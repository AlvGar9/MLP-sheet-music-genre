# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns
import numpy as np

import os

# %%
# Path to the CSV file
current_directory = os.getcwd()
file_path = os.path.join(current_directory, "archives", "PDMX.csv")
df = pd.read_csv(file_path)

# %% [markdown]
# Having loaded the CSV, we perform a little analysis of the dataset.

# %%
df.head()
# Out:
#                                                 path  \
# 0  ./data/1/11/QmbbGKtZ9G6DkWxvSeU516c1ktWiFJmEbH...
# 1  ./data/1/11/QmbbWCwo3rhaJ2wKL6H7aQPX9D6HfQxLZK...
# 2  ./data/1/11/QmbbhLwwmuKqA9MC1ULhojEMGxnxDobsZP...
# 3  ./data/1/11/Qmbbh58jD1ZLT1vevNsnyEZkexnx2USTFz...
# 4  ./data/1/11/Qmbbmnu3Eg81nQ3WHnBFrAj5gsr3D13ysS...
#
#                     metadata  \
# 0  ./metadata/5/5740212.json
# 1  ./metadata/2/5736259.json
# 2  ./metadata/1/4571401.json
# 3  ./metadata/6/4694088.json
# 4  ./metadata/4/4808199.json
#
#                                                  mxl  \
# 0  ./mxl/1/11/QmbbGKtZ9G6DkWxvSeU516c1ktWiFJmEbHG...
# 1  ./mxl/1/11/QmbbWCwo3rhaJ2wKL6H7aQPX9D6HfQxLZKP...
# 2  ./mxl/1/11/QmbbhLwwmuKqA9MC1ULhojEMGxnxDobsZPJ...
# 3  ./mxl/1/11/Qmbbh58jD1ZLT1vevNsnyEZkexnx2USTFz6...
# 4  ./mxl/1/11/Qmbbmnu3Eg81nQ3WHnBFrAj5gsr3D13ysSQ...
#
#                                                  pdf  version  is_user_pro  \
# 0  ./pdf/1/11/QmbbGKtZ9G6DkWxvSeU516c1ktWiFJmEbHG...     3.01         True
# 1  ./pdf/1/11/QmbbWCwo3rhaJ2wKL6H7aQPX9D6HfQxLZKP...     3.01         True
# 2  ./pdf/1/11/QmbbhLwwmuKqA9MC1ULhojEMGxnxDobsZPJ...     3.01         True
# 3  ./pdf/1/11/Qmbbh58jD1ZLT1vevNsnyEZkexnx2USTFz6...     3.01         True
# 4  ./pdf/1/11/Qmbbmnu3Eg81nQ3WHnBFrAj5gsr3D13ysSQ...     3.01         True
#
#    is_user_publisher  is_user_staff  has_paywall  is_rated  ...  \
# 0              False          False        False      True  ...
# 1              False          False        False     False  ...
# 2              False          False        False     False  ...
# 3              False          False        False     False  ...
# 4              False          False        False     False  ...
#
#                                     best_arrangement  is_best_arrangement  \
# 0  ./data/1/11/QmbbGKtZ9G6DkWxvSeU516c1ktWiFJmEbH...                 True
# 1  ./data/4/20/QmeFmHKn3UF4o56vThLV4kwXhpTNDd9gH9...                False
# 2  ./data/0/9/QmaahMHX51JmiE3LZUbdFpvTTuMdiV8Uvmv...                False
# 3  ./data/13/1/QmV2RMMZuHxhgQqEUV98FpFGJ5mPuDVSXy...                False
# 4  ./data/5/4/Qmf5QQhwvkXMmNtjG8ydfNRFq5yBDvhQbfQ...                False
#
#                              best_unique_arrangement  \
# 0  ./data/1/11/QmbbGKtZ9G6DkWxvSeU516c1ktWiFJmEbH...
# 1  ./data/4/20/QmeFmHKn3UF4o56vThLV4kwXhpTNDd9gH9...
# 2  ./data/0/9/QmaahMHX51JmiE3LZUbdFpvTTuMdiV8Uvmv...
# 3  ./data/13/1/QmV2RMMZuHxhgQqEUV98FpFGJ5mPuDVSXy...
# 4  ./data/5/4/Qmf5QQhwvkXMmNtjG8ydfNRFq5yBDvhQbfQ...
#
#    is_best_unique_arrangement  subset:all  subset:rated  subset:deduplicated  \
# 0                        True        True          True                 True
# 1                       False        True         False                False
# 2                       False        True         False                False
# 3                       False        True         False                False
# 4                       False        True         False                False
#
#    subset:rated_deduplicated  subset:no_license_conflict  subset:valid_mxl_pdf
# 0                       True                       False                  True
# 1                      False                       False                  True
# 2                      False                        True                  True
# 3                      False                        True                  True
# 4                      False                        True                  True
#
# [5 rows x 61 columns]

# %%
df.columns
# Out:
# Index(['path', 'metadata', 'mxl', 'pdf', 'version', 'is_user_pro',
#        'is_user_publisher', 'is_user_staff', 'has_paywall', 'is_rated',
#        'is_official', 'is_original', 'is_draft', 'has_custom_audio',
#        'has_custom_video', 'n_comments', 'n_favorites', 'n_views', 'n_ratings',
#        'rating', 'license', 'license_url', 'license_conflict', 'genres',
#        'groups', 'tags', 'song_name', 'title', 'subtitle', 'artist_name',
#        'composer_name', 'publisher', 'complexity', 'n_tracks', 'tracks',
#        'song_length', 'song_length.seconds', 'song_length.bars',
#        'song_length.beats', 'n_notes', 'notes_per_bar', 'n_annotations',
#        'has_annotations', 'n_lyrics', 'has_lyrics', 'n_tokens',
#        'pitch_class_entropy', 'scale_consistency', 'groove_consistency',
#        'best_path', 'is_best_path', 'best_arrangement', 'is_best_arrangement',
#        'best_unique_arrangement', 'is_best_unique_arrangement', 'subset:all',
#        'subset:rated', 'subset:deduplicated', 'subset:rated_deduplicated',
#        'subset:no_license_conflict', 'subset:valid_mxl_pdf'],
#       dtype='object')

# %%
n_songs = len(df)
n_unlabeled = df['genres'].isnull().sum()

print("Number of songs in the dataset: ", n_songs)
print("Number of songs without genre: ",  n_unlabeled)
print("Number of labelled songs: ",  n_songs - n_unlabeled)
# Out:
# Number of songs in the dataset:  254077
# Number of songs without genre:  171276
# Number of labelled songs:  82801

# %% [markdown]
# We now count and visualise the distribution of genres in the dataset.

# %%
# Convert genres to string and split for multi-label instances
df['genres'] = df['genres'].astype(str)  
genre_series = df['genres'].str.split('-')  

# Flatten the list of genres and count occurrences
all_genres = [genre.strip() for sublist in genre_series for genre in sublist]
genre_counts = Counter(all_genres)

# DataFrame for visualization
genre_df = pd.DataFrame(genre_counts.items(), columns=['Genre', 'Count']).sort_values(by='Count', ascending=False)
print(genre_df)

plt.figure(figsize=(14, 7))
sns.barplot(x=genre_df['Genre'][:21], y=genre_df['Count'][:21], hue=genre_df['Genre'][:21], legend="auto", palette="colorblind")
plt.xticks(rotation=45, ha="right", fontsize=12)
plt.xlabel("Genre", fontsize=14, fontweight='bold')
plt.ylabel("Count", fontsize=14, fontweight='bold')
plt.title("Top 20 Music Genres in PDMX Dataset", fontsize=16, fontweight='bold', color='darkred')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
#              Genre   Count
# 1              nan  171276
# 0        classical   64586
# 3             folk   11076
# 5       soundtrack    3461
# 4             rock    1668
# 7              pop    1544
# 8             jazz     647
# 12      electronic     581
# 11      rbfunksoul     494
# 2   religiousmusic     460
# 6       worldmusic     337
# 10          hiphop     220
# 16           metal     149
# 9     experimental     126
# 15         country     122
# 14          newage      59
# 17          comedy      43
# 13           disco      39
# 19       reggaeska      18
# 18           blues      16
# 20        darkwave       3
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_191561/2173860006.py in <module>
#      12
#      13 plt.figure(figsize=(14, 7))
# ---> 14 sns.barplot(x=genre_df['Genre'][:21], y=genre_df['Count'][:21], hue=genre_df['Genre'][:21], legend="auto", palette="colorblind")
#      15 plt.xticks(rotation=45, ha="right", fontsize=12)
#      16 plt.xlabel("Genre", fontsize=14, fontweight='bold')
#
# /usr/lib/python3/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/lib/python3/dist-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3188         ax = plt.gca()
#    3189
# -> 3190     plotter.plot(ax, kwargs)
#    3191     return ax
#    3192
#
# /usr/lib/python3/dist-packages/seaborn/categorical.py in plot(self, ax, bar_kws)
#    1637     def plot(self, ax, bar_kws):
#    1638         """Make the plot."""
# -> 1639         self.draw_bars(ax, bar_kws)
#    1640         self.annotate_axes(ax)
#    1641         if self.orient == "h":
#
# /usr/lib/python3/dist-packages/seaborn/categorical.py in draw_bars(self, ax, kws)
#    1620                 # Draw the bars
#    1621                 offpos = barpos + self.hue_offsets[j]
# -> 1622                 barfunc(offpos, self.statistic[:, j], self.nested_width,
#    1623                         color=self.colors[j], align="center",
#    1624                         label=hue_level, **kws)
#
# /usr/lib/python3/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1414     def inner(ax, *args, data=None, **kwargs):
#    1415         if data is None:
# -> 1416             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1417
#    1418         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2401                 hatch=htch,
#    2402                 )
# -> 2403             r.update(kwargs)
#    2404             r.get_path()._interpolation_steps = 100
#    2405             if orientation == 'vertical':
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property 'legend'

# %% [markdown]
# Some rows (songs) have multiple genres associated to them, we count how many intances of those happen.

# %%
# Count multi-label instances (songs with more than one genre)
multi_label_instances = sum(1 for genres in genre_series if len(genres) > 1)
print(f"Number of multi-label instances (songs with multiple genres): {multi_label_instances}")
# Out:
# Number of multi-label instances (songs with multiple genres): 2727

# %%
# We convert any non-standard NaN representations to actual NaN
df['genres'] = df['genres'].replace(['nan', 'NaN', 'None', ''], np.nan)
df = df.dropna(subset=['genres'])

# %% [markdown]
# After the removal of Nan entries we plot the resulting distribution, log transformed in the y axis for better visualisation, due to the hihg class imbalance.

# %%
# Convert genres to string and split for multi-label instances
df['genres'] = df['genres'].astype(str)  
genre_series = df['genres'].str.split('-')  

# Flatten the list of genres and count occurrences
all_genres = [genre.strip() for sublist in genre_series for genre in sublist]
genre_counts = Counter(all_genres)

# DataFrame for visualization
genre_df = pd.DataFrame(genre_counts.items(), columns=['Genre', 'Count']).sort_values(by='Count', ascending=False)
print(genre_df)

plt.figure(figsize=(14, 7))
sns.barplot(x=genre_df['Genre'][:20], y=genre_df['Count'][:20], hue=genre_df['Genre'][:20], legend="auto", palette="colorblind")
plt.yscale("log")
plt.xticks(rotation=45, ha="right", fontsize=12)
plt.xlabel("Genre", fontsize=14, fontweight='bold')
plt.ylabel("Count", fontsize=14, fontweight='bold')
plt.title("Top 20 Music Genres in PDMX Dataset (log transformed)", fontsize=16, fontweight='bold', color='darkred')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
#              Genre  Count
# 0        classical  64586
# 2             folk  11076
# 4       soundtrack   3461
# 3             rock   1668
# 6              pop   1544
# 7             jazz    647
# 11      electronic    581
# 10      rbfunksoul    494
# 1   religiousmusic    460
# 5       worldmusic    337
# 9           hiphop    220
# 15           metal    149
# 8     experimental    126
# 14         country    122
# 13          newage     59
# 16          comedy     43
# 12           disco     39
# 18       reggaeska     18
# 17           blues     16
# 19        darkwave      3
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_191561/612092162.py in <module>
#      12
#      13 plt.figure(figsize=(14, 7))
# ---> 14 sns.barplot(x=genre_df['Genre'][:20], y=genre_df['Count'][:20], hue=genre_df['Genre'][:20], legend="auto", palette="colorblind")
#      15 plt.yscale("log")
#      16 plt.xticks(rotation=45, ha="right", fontsize=12)
#
# /usr/lib/python3/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/lib/python3/dist-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3188         ax = plt.gca()
#    3189
# -> 3190     plotter.plot(ax, kwargs)
#    3191     return ax
#    3192
#
# /usr/lib/python3/dist-packages/seaborn/categorical.py in plot(self, ax, bar_kws)
#    1637     def plot(self, ax, bar_kws):
#    1638         """Make the plot."""
# -> 1639         self.draw_bars(ax, bar_kws)
#    1640         self.annotate_axes(ax)
#    1641         if self.orient == "h":
#
# /usr/lib/python3/dist-packages/seaborn/categorical.py in draw_bars(self, ax, kws)
#    1620                 # Draw the bars
#    1621                 offpos = barpos + self.hue_offsets[j]
# -> 1622                 barfunc(offpos, self.statistic[:, j], self.nested_width,
#    1623                         color=self.colors[j], align="center",
#    1624                         label=hue_level, **kws)
#
# /usr/lib/python3/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1414     def inner(ax, *args, data=None, **kwargs):
#    1415         if data is None:
# -> 1416             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1417
#    1418         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2401                 hatch=htch,
#    2402                 )
# -> 2403             r.update(kwargs)
#    2404             r.get_path()._interpolation_steps = 100
#    2405             if orientation == 'vertical':
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property 'legend'

# %% [markdown]
# Save CSV without nans for correct manipulation of the files.

# %%
df.to_csv('dataset.csv', index=False)  # Set index=False to avoid saving the index column

print("CSV file saved successfully!")
# Out:
# CSV file saved successfully!

# %%
df.head()
# Out:
#                                                  path  \
# 0   ./data/1/11/QmbbGKtZ9G6DkWxvSeU516c1ktWiFJmEbH...
# 1   ./data/1/11/QmbbWCwo3rhaJ2wKL6H7aQPX9D6HfQxLZK...
# 14  ./data/1/11/QmbbPY7NB4Gkj1qciLjhF99KHyLmiWGiCu...
# 16  ./data/1/11/Qmbbi1chUBP7x2jJG2omBZBjc15mEAFfeL...
# 17  ./data/1/11/QmbbWAiF7Eg8RapgdgwzRwgd4F4JFVmD5J...
#
#                      metadata  \
# 0   ./metadata/5/5740212.json
# 1   ./metadata/2/5736259.json
# 14  ./metadata/0/5736329.json
# 16  ./metadata/2/5740388.json
# 17  ./metadata/2/5014656.json
#
#                                                   mxl  \
# 0   ./mxl/1/11/QmbbGKtZ9G6DkWxvSeU516c1ktWiFJmEbHG...
# 1   ./mxl/1/11/QmbbWCwo3rhaJ2wKL6H7aQPX9D6HfQxLZKP...
# 14  ./mxl/1/11/QmbbPY7NB4Gkj1qciLjhF99KHyLmiWGiCuJ...
# 16  ./mxl/1/11/Qmbbi1chUBP7x2jJG2omBZBjc15mEAFfeLY...
# 17  ./mxl/1/11/QmbbWAiF7Eg8RapgdgwzRwgd4F4JFVmD5JY...
#
#                                                   pdf  version  is_user_pro  \
# 0   ./pdf/1/11/QmbbGKtZ9G6DkWxvSeU516c1ktWiFJmEbHG...     3.01         True
# 1   ./pdf/1/11/QmbbWCwo3rhaJ2wKL6H7aQPX9D6HfQxLZKP...     3.01         True
# 14  ./pdf/1/11/QmbbPY7NB4Gkj1qciLjhF99KHyLmiWGiCuJ...     3.01         True
# 16  ./pdf/1/11/Qmbbi1chUBP7x2jJG2omBZBjc15mEAFfeLY...     3.01         True
# 17  ./pdf/1/11/QmbbWAiF7Eg8RapgdgwzRwgd4F4JFVmD5JY...     3.01         True
#
#     is_user_publisher  is_user_staff  has_paywall  is_rated  ...  \
# 0               False          False        False      True  ...
# 1               False          False        False     False  ...
# 14              False          False        False     False  ...
# 16              False          False        False     False  ...
# 17              False          False        False     False  ...
#
#                                      best_arrangement  is_best_arrangement  \
# 0   ./data/1/11/QmbbGKtZ9G6DkWxvSeU516c1ktWiFJmEbH...                 True
# 1   ./data/4/20/QmeFmHKn3UF4o56vThLV4kwXhpTNDd9gH9...                False
# 14  ./data/5/20/QmfFUe9dBjwXr4PbykQhz3vRhXyzzJtVag...                False
# 16  ./data/1/6/Qmb7sYXjaLnEUkqz1148D8EKY6fe2gKWiVH...                False
# 17  ./data/11/19/QmTf9KtHa9QaDQzC235YmUcGoGv3CVYe2...                False
#
#                               best_unique_arrangement  \
# 0   ./data/1/11/QmbbGKtZ9G6DkWxvSeU516c1ktWiFJmEbH...
# 1   ./data/4/20/QmeFmHKn3UF4o56vThLV4kwXhpTNDd9gH9...
# 14  ./data/1/11/QmbbPY7NB4Gkj1qciLjhF99KHyLmiWGiCu...
# 16  ./data/1/11/Qmbbi1chUBP7x2jJG2omBZBjc15mEAFfeL...
# 17  ./data/12/11/QmUbe2w8Vk7bNMdEReKZ8CUGWkV79ZaEj...
#
#     is_best_unique_arrangement  subset:all  subset:rated  subset:deduplicated  \
# 0                         True        True          True                 True
# 1                        False        True         False                False
# 14                        True        True         False                 True
# 16                        True        True         False                 True
# 17                       False        True         False                False
#
#     subset:rated_deduplicated  subset:no_license_conflict  \
# 0                        True                       False
# 1                       False                       False
# 14                      False                       False
# 16                      False                       False
# 17                      False                        True
#
#     subset:valid_mxl_pdf
# 0                   True
# 1                   True
# 14                  True
# 16                  True
# 17                  True
#
# [5 rows x 61 columns]

# %%
from score_to_tokens import MusicXML_to_tokens
tokens = MusicXML_to_tokens('SchbAvMaSample.musicxml', bar_major=True, tokenize_chord_symbols=True)
print(tokens)
# Out:
# ['bar', 'key_flat_2', 'time_4/4', 'R', 'clef_treble', 'rest', 'len_4', 'L', 'clef_treble', 'clef_bass', 'rest', 'len_1/6', 'note_D4', 'note_F4', 'len_1/6', 'stem_up', 'beam_start_start', 'staccato', 'slur_start', 'note_F4', 'note_Bb4', 'len_1/6', 'stem_up', 'beam_continue_continue', 'staccato', 'note_Bb4', 'note_D5', 'len_1/6', 'stem_up', 'beam_continue_continue', 'staccato', 'accent', 'note_F4', 'note_Bb4', 'len_1/6', 'stem_up', 'beam_continue_continue', 'staccato', 'note_D4', 'note_F4', 'len_1/6', 'stem_up', 'beam_stop_stop', 'staccato', 'slur_stop', 'rest', 'len_1/6', 'note_D4', 'note_F4', 'len_1/6', 'stem_up', 'beam_start_start', 'staccato', 'slur_start', 'note_F4', 'note_Bb4', 'len_1/6', 'stem_up', 'beam_continue_continue', 'staccato', 'note_Bb4', 'note_D5', 'len_1/6', 'stem_up', 'beam_continue_continue', 'staccato', 'accent', 'note_F4', 'note_Bb4', 'len_1/6', 'stem_up', 'beam_continue_continue', 'staccato', 'note_D4', 'note_F4', 'len_1/6', 'stem_up', 'beam_stop_stop', 'staccato', 'slur_stop', 'rest', 'len_1/6', 'note_F4', 'note_Bb4', 'len_1/6', 'stem_down', 'beam_start_start', 'staccato', 'slur_start', 'note_Bb4', 'note_D5', 'len_1/6', 'stem_down', 'beam_continue_continue', 'staccato', 'note_D5', 'note_F5', 'len_1/6', 'stem_down', 'beam_continue_continue', 'staccato', 'accent', 'note_Bb4', 'note_D5', 'len_1/6', 'stem_down', 'beam_continue_continue', 'staccato', 'note_F4', 'note_Bb4', 'len_1/6', 'stem_down', 'beam_stop_stop', 'staccato', 'slur_stop', 'rest', 'len_1/6', 'note_Ab4', 'note_D5', 'len_1/6', 'stem_down', 'beam_start_start', 'staccato', 'slur_start', 'note_D5', 'note_F5', 'len_1/6', 'stem_down', 'beam_continue_continue', 'staccato', 'note_F5', 'note_Ab5', 'len_1/6', 'stem_down', 'beam_continue_continue', 'staccato', 'accent', 'note_D5', 'note_F5', 'len_1/6', 'stem_down', 'beam_continue_continue', 'staccato', 'note_Ab4', 'note_D5', 'len_1/6', 'stem_down', 'beam_stop_stop', 'staccato', 'slur_stop', 'note_Bb1', 'note_Bb2', 'len_1/2', 'stem_up', 'rest', 'len_1/2', 'note_Bb1', 'note_Bb2', 'len_1/2', 'stem_up', 'rest', 'len_1/2', 'note_Bb1', 'note_Bb2', 'len_1/2', 'stem_up', 'rest', 'len_1/2', 'note_Bb1', 'note_Bb2', 'len_1/2', 'stem_up', 'rest', 'len_1/2', 'bar', 'R', 'rest', 'len_4', 'L', 'rest', 'len_1/6', 'note_G4', 'note_Bb4', 'len_1/6', 'stem_down', 'beam_start_start', 'staccato', 'slur_start', 'note_Bb4', 'note_Eb5', 'len_1/6', 'stem_down', 'beam_continue_continue', 'staccato', 'note_Eb5', 'note_G5', 'len_1/6', 'stem_down', 'beam_continue_continue', 'staccato', 'accent', 'note_Bb4', 'note_Eb5', 'len_1/6', 'stem_down', 'beam_continue_continue', 'staccato', 'note_G4', 'note_Bb4', 'len_1/6', 'stem_down', 'beam_stop_stop', 'staccato', 'slur_stop', 'rest', 'len_1/6', 'note_Gb4', 'note_A4', 'len_1/6', 'stem_down', 'beam_start_start', 'staccato', 'slur_start', 'note_A4', 'note_Eb5', 'len_1/6', 'stem_down', 'beam_continue_continue', 'staccato', 'note_Eb5', 'note_Gb5', 'len_1/6', 'stem_down', 'beam_continue_continue', 'staccato', 'accent', 'note_A4', 'note_Eb5', 'len_1/6', 'stem_down', 'beam_continue_continue', 'staccato', 'note_Gb4', 'note_A4', 'len_1/6', 'stem_down', 'beam_stop_stop', 'staccato', 'slur_stop', 'rest', 'len_1/6', 'note_F4', 'note_Bb4', 'len_1/6', 'stem_down', 'beam_start_start', 'staccato', 'slur_start', 'note_Bb4', 'note_D5', 'len_1/6', 'stem_down', 'beam_continue_continue', 'staccato', 'note_D5', 'note_F5', 'len_1/6', 'stem_down', 'beam_continue_continue', 'staccato', 'accent', 'note_Bb4', 'note_D5', 'len_1/6', 'stem_down', 'beam_continue_continue', 'staccato', 'note_F4', 'note_Bb4', 'len_1/6', 'stem_down', 'beam_stop_stop', 'staccato', 'slur_stop', 'rest', 'len_1/6', 'note_D4', 'note_F4', 'len_1/6', 'stem_up', 'beam_start_start', 'staccato', 'slur_start', 'note_F4', 'note_Bb4', 'len_1/6', 'stem_up', 'beam_continue_continue', 'staccato', 'note_Bb4', 'note_D5', 'len_1/6', 'stem_up', 'beam_continue_continue', 'staccato', 'accent', 'note_F4', 'note_Bb4', 'len_1/6', 'stem_up', 'beam_continue_continue', 's ...
