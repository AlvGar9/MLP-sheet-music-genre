# %% [markdown]
# # NLP Genre Classifier

# %% [markdown]
# ## Imports

# %%
import os
import csv
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import math
from collections import Counter
import time

from mxl_tokenizer import MusicXML_to_tokens

# %% [markdown]
# ## Data Loader

# %%
class MusicXMLDataset(Dataset):
    def __init__(self, csv_path, vocab=None, max_len=512):
        self.entries = []
        with open(csv_path, 'r', encoding='utf-8') as f:
            reader = csv.DictReader(f)
            for row in reader:
                for i in range(2):
                    if ("./mxl/0/" + str(i) + "/") in row['mxl']: # DEBUG: use a subset for now
                        self.entries.append(row)
        
        # Enumerate unique genres from the "primary_genre" field.
        unique_genres = set(entry['primary_genre'] for entry in self.entries)
        print("PRIMARY GENRES:", unique_genres)
        self.genre_to_idx = {genre: idx for idx, genre in enumerate(sorted(unique_genres))}

        self.max_len = max_len
        # Build vocabulary if not provided
        if vocab is None:
            self.vocab = self.build_vocab()
        else:
            self.vocab = vocab

    def build_vocab(self):
        counter = Counter()
        # For each MusicXML file, get tokens using the provided tokenizer.
        for entry in self.entries:
            path = entry['mxl'].replace("./mxl/", "../data/mxl/")
            try:
                tokens = MusicXML_to_tokens(path)
            except Exception as e:
                print(f"Error tokenizing {path}: {e}")
                tokens = []
            counter.update(tokens)
        # Create vocab with special tokens
        vocab = {'<PAD>': 0, '<UNK>': 1, '<CLS>': 2}
        for token, _ in counter.items():
            if token not in vocab:
                vocab[token] = len(vocab)
        return vocab

    def tokenize_and_pad(self, mxml_path):
        try:
            tokens = MusicXML_to_tokens(mxml_path)
        except Exception as e:
            print(f"Error tokenizing {mxml_path}: {e}")
            tokens = []
        # Prepend a <CLS> token for classification
        tokens = ['<CLS>'] + tokens
        token_ids = [self.vocab.get(tok, self.vocab['<UNK>']) for tok in tokens]
        # Truncate or pad to max_len
        if len(token_ids) > self.max_len:
            token_ids = token_ids[:self.max_len]
        else:
            token_ids = token_ids + [self.vocab['<PAD>']] * (self.max_len - len(token_ids))
        return torch.tensor(token_ids, dtype=torch.long)

    def __len__(self):
        return len(self.entries)

    def __getitem__(self, idx):
        entry = self.entries[idx]
        mxml_path = entry['mxl'].replace("./mxl/", "../data/mxl/")
        # Tokenize using your custom tokenizer
        token_ids = self.tokenize_and_pad(mxml_path)
        
        # Convert genre string into an integer label using the mapping.
        genre_str = entry['primary_genre']
        genre = self.genre_to_idx[genre_str]
        
        return token_ids, genre

# %% [markdown]
# ## Define Positional Encoding

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=512):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        if d_model % 2 == 1:
            # if odd, handle last column
            pe[:, 1::2] = torch.cos(position * div_term[:pe[:, 1::2].shape[1]])
        else:
            pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)  # Shape: (1, max_len, d_model)
        self.register_buffer('pe', pe)

    def forward(self, x):
        # x shape: (batch_size, seq_len, d_model)
        x = x + self.pe[:, :x.size(1)]
        return x

# %% [markdown]
# ## Define Model

# %%
class TransformerClassifier(nn.Module):
    def __init__(self, vocab_size, d_model=512, nhead=8, num_layers=6, num_classes=10, max_len=512, dropout=0.1):
        super(TransformerClassifier, self).__init__()
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model, max_len)
        encoder_layer = nn.TransformerEncoderLayer(d_model, nhead, dim_feedforward=2048, dropout=dropout)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers)
        self.dropout = nn.Dropout(dropout)
        # Classifier head: you can use the <CLS> token embedding or a pooling over sequence outputs
        self.fc = nn.Linear(d_model, num_classes)

    def forward(self, src):
        # src shape: (batch_size, seq_len)
        embedded = self.embedding(src)  # (batch_size, seq_len, d_model)
        embedded = self.pos_encoder(embedded)
        # PyTorch transformer expects shape: (seq_len, batch_size, d_model)
        embedded = embedded.transpose(0, 1)
        transformer_output = self.transformer_encoder(embedded)  # (seq_len, batch_size, d_model)
        # Take the output corresponding to the <CLS> token (first token)
        cls_output = transformer_output[0]  # (batch_size, d_model)
        cls_output = self.dropout(cls_output)
        logits = self.fc(cls_output)
        return logits

# %% [markdown]
# ## Train Model

# %%
def train_model(model, dataloader, optimizer, criterion, device):
    model.train()
    total_loss = 0.
    for token_ids, labels in dataloader:
        token_ids, labels = token_ids.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = model(token_ids)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(dataloader)

def evaluate_model(model, dataloader, criterion, device):
    model.eval()
    total_loss = 0.
    correct = 0
    total = 0
    with torch.no_grad():
        for token_ids, labels in dataloader:
            token_ids, labels = token_ids.to(device), labels.to(device)
            logits = model(token_ids)
            loss = criterion(logits, labels)
            total_loss += loss.item()
            preds = logits.argmax(dim=1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)
    accuracy = correct / total
    return total_loss / len(dataloader), accuracy

# %% [markdown]
# ## Test Model

# %%
# Testing function
def test_model(model, dataloader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for features, labels in dataloader:
            outputs = model(features)
            predictions = torch.argmax(outputs, dim=1)
            correct += (predictions == labels).sum().item()
            total += labels.size(0)
    accuracy = 100 * correct / total if total > 0 else 0
    print(f"Test Accuracy: {accuracy:.2f}%")

# %% [markdown]
# ## Run

# %%
if __name__ == '__main__':
    # Hyperparameters
    csv_path = 'dataset.csv'
    max_len = 512
    batch_size = 32
    num_classes = 7  # Adjust according to your dataset
    d_model = 512
    nhead = 8
    num_layers = 6
    num_epochs = 100
    learning_rate = 1e-4

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Create dataset and split into training/validation sets
    dataset = MusicXMLDataset(csv_path, max_len=max_len)
    vocab_size = len(dataset.vocab)
    train_size = int(0.8 * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size)

    # Instantiate model, optimizer, and loss function
    model = TransformerClassifier(vocab_size, d_model=d_model, nhead=nhead, 
                                  num_layers=num_layers, num_classes=num_classes, 
                                  max_len=max_len).to(device)
    optimizer = optim.AdamW(model.parameters(), lr=learning_rate)
    criterion = nn.CrossEntropyLoss()

    # Training loop
    for epoch in range(num_epochs):
        start_time = time.time()  # Start timer for the epoch
    
        train_loss = train_model(model, train_loader, optimizer, criterion, device)
        val_loss, val_acc = evaluate_model(model, val_loader, criterion, device)
        
        epoch_time = time.time() - start_time  # Compute elapsed time for the epoch
        print(f"Epoch {epoch+1}: Train Loss = {train_loss:.4f}, Val Loss = {val_loss:.4f}, Val Acc = {val_acc:.4f}")
# Out:
# PRIMARY GENRES: {'Soundtrack', 'Religious', 'Rock & Metal', 'Electronic & Dance', 'Classical', 'Folk/World', 'Pop'}
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# c:\Python312\Lib\site-packages\torch\nn\modules\transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 1: Train Loss = 1.9729, Val Loss = 1.3352, Val Acc = 0.6429
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 2: Train Loss = 1.4907, Val Loss = 1.4373, Val Acc = 0.6429
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 3: Train Loss = 1.3055, Val Loss = 1.5942, Val Acc = 0.6429
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 4: Train Loss = 1.3047, Val Loss = 1.6458, Val Acc = 0.5714
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 5: Train Loss = 1.2676, Val Loss = 1.5826, Val Acc = 0.6429
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 6: Train Loss = 1.2555, Val Loss = 1.5220, Val Acc = 0.6429
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 7: Train Loss = 1.1823, Val Loss = 1.5017, Val Acc = 0.6429
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 8: Train Loss = 1.1194, Val Loss = 1.4868, Val Acc = 0.6429
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 9: Train Loss = 1.1389, Val Loss = 1.4967, Val Acc = 0.6429
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 10: Train Loss = 1.0430, Val Loss = 1.5224, Val Acc = 0.5714
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 11: Train Loss = 1.0656, Val Loss = 1.5282, Val Acc = 0.6429
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 12: Train Loss = 1.0704, Val Loss = 1.5097, Val Acc = 0.6429
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 13: Train Loss = 0.9620, Val Loss = 1.4593, Val Acc = 0.5714
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 14: Train Loss = 0.9211, Val Loss = 1.4451, Val Acc = 0.5714
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 15: Train Loss = 0.8411, Val Loss = 1.4667, Val Acc = 0.5714
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 16: Train Loss = 0.8128, Val Loss = 1.5474, Val Acc = 0.5714
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 17: Train Loss = 0.7503, Val Loss = 1.5928, Val Acc = 0.5714
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 18: Train Loss = 0.6932, Val Loss = 1.6547, Val Acc = 0.5714
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 19: Train Loss = 0.6482, Val Loss = 1.8212, Val Acc = 0.5714
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 20: Train Loss = 0.5653, Val Loss = 2.0103, Val Acc = 0.5714
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 21: Train Loss = 0.5374, Val Loss = 2.0407, Val Acc = 0.5714
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 22: Train Loss = 0.4834, Val Loss = 2.2335, Val Acc = 0.5714
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 23: Train Loss = 0.3338, Val Loss = 2.3174, Val Acc = 0.5714
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 24: Train Loss = 0.3277, Val Loss = 2.3788, Val Acc = 0.6429
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 25: Train Loss = 0.2853, Val Loss = 2.6227, Val Acc = 0.5714
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 26: Train Loss = 0.2129, Val Loss = 2.7778, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 27: Train Loss = 0.2154, Val Loss = 2.6624, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 28: Train Loss = 0.1639, Val Loss = 2.7882, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 29: Train Loss = 0.1224, Val Loss = 2.9892, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 30: Train Loss = 0.1193, Val Loss = 3.0224, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 31: Train Loss = 0.1467, Val Loss = 2.9572, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 32: Train Loss = 0.1834, Val Loss = 3.2326, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 33: Train Loss = 0.3064, Val Loss = 3.0147, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 34: Train Loss = 0.1735, Val Loss = 3.1375, Val Acc = 0.4286
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 35: Train Loss = 0.3562, Val Loss = 2.9084, Val Acc = 0.5714
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 36: Train Loss = 0.0646, Val Loss = 2.9937, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 37: Train Loss = 0.1696, Val Loss = 2.9595, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 38: Train Loss = 0.1364, Val Loss = 2.8996, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 39: Train Loss = 0.0653, Val Loss = 2.9537, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 40: Train Loss = 0.0967, Val Loss = 2.9312, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 41: Train Loss = 0.0799, Val Loss = 2.8660, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 42: Train Loss = 0.0570, Val Loss = 2.9526, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 43: Train Loss = 0.0561, Val Loss = 3.1995, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 44: Train Loss = 0.0763, Val Loss = 3.3501, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 45: Train Loss = 0.0522, Val Loss = 3.3653, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 46: Train Loss = 0.0613, Val Loss = 3.3462, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 47: Train Loss = 0.0533, Val Loss = 3.3021, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 48: Train Loss = 0.0277, Val Loss = 3.3283, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 49: Train Loss = 0.0565, Val Loss = 3.3602, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# Error tokenizing ../data/mxl/0/1/Qma2FqBY8JAg9sd28YkMptu2dkHgDzJPpeK5Xq4vtxs6x7.mxl: In part (Church Organ, Staff), measure (24): Cannot convert inexpressible durations to MusicXML.
# Error tokenizing ../data/mxl/0/1/Qma2qXH7BTNA9mf19TPCYLmsP5sZBDxJ3SzdNi7oQVdqyT.mxl: Cannot insert None into a tag.
# Epoch 50: Train Loss = 0.0257, Val Loss = 3.3730, Val Acc = 0.5000
# Error tokenizing ../data/mxl/0/1/Qma2M87ZgTYMGXmzKucfA1RN2gggRWdQu5JFVj3R84QvpF.mxl: In part (Part_1), measure (76): Cannot convert "2048th" duration to MusicXML (too short).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 35
#      32 for epoch in range(num_epochs):
#      33     start_time = time.time()  # Start timer for the epoch
# ---> 35     train_loss = train_model(model, train_loader, optimizer, criterion, device)
#      36     val_loss, val_acc = evaluate_model(model, val_loader, criterion, device)
#      38     epoch_time = time.time() - start_time  # Compute elapsed time for the epoch
#
# Cell In[19], line 4, in train_model(model, dataloader, optimizer, criterion, device)
#       2 model.train()
#       3 total_loss = 0.
# ----> 4 for token_ids, labels in dataloader:
#       5     token_ids, labels = token_ids.to(device), labels.to(device)
#       6     optimizer.zero_grad()
#
# File c:\Python312\Lib\site-packages\torch\utils\data\dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File c:\Python312\Lib\site-packages\torch\utils\data\dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Python312\Lib\site-packages\torch\utils\data\_utils\fetch.py:50, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      48 if self.auto_collation:
#      49     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
#      52         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File c:\Python312\Lib\site-packages\torch\utils\data\dataset.py:420, in Subset.__getitems__(self, indices)
#     418     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     419 else:
# --> 420     return [self.dataset[self.indices[idx]] for idx in indices]
#
# Cell In[16], line 64, in MusicXMLDataset.__getitem__(self, idx)
#      62 mxml_path = entry['mxl'].replace("./mxl/", "../data/mxl/")
#      63 # Tokenize using your custom tokenizer
# ---> 64 token_ids = self.tokenize_and_pad(mxml_path)
#      66 # Convert genre string into an integer label using the mapping.
#      67 genre_str = entry['primary_genre']
#
# Cell In[16], line 43, in MusicXMLDataset.tokenize_and_pad(self, mxml_path)
#      41 def tokenize_and_pad(self, mxml_path):
#      42     try:
# ---> 43         tokens = MusicXML_to_tokens(mxml_path)
#      44     except Exception as e:
#      45         print(f"Error tokenizing {mxml_path}: {e}")
#
# File c:\Users\Cameron\Desktop\MLP\code\mxl_tokenizer.py:413, in MusicXML_to_tokens(mxml_path, bar_major, note_name, tokenize_chord_symbols)
#     402 def MusicXML_to_tokens(mxml_path, bar_major=True, note_name=True, tokenize_chord_symbols=True):
#     403     """
#     404     Converts a MusicXML or MXL file to a list of tokens.
#     405     This updated version supports an arbitrary number of parts.
#    (...)    411     In non-bar_major mode, tokens for each part are concatenated with a part marker.
#     412     """
# --> 413     parts, soup = load_MusicXML(mxml_path)
#     414     num_parts = len(parts)
#     416     # Remove the old check; now we support any number of parts.
#     417     # if not len(parts) in (1, 2):
#     418     #     print(f"This function only supports 1 or 2 parts. The input file has {len(parts)} parts.")
#     419     # assert len(parts) in (1, 2)
#     420
#     421     # Optionally, tokenize chord symbols from the full score.
#
# File c:\Users\Cameron\Desktop\MLP\code\mxl_tokenizer.py:393, in load_MusicXML(file_path)
#     390         raw_data = f.read()
#     392 # Parse the MusicXML data with BeautifulSoup
# --> 393 soup = BeautifulSoup(raw_data, 'lxml-xml')
#     395 # Eliminate line breaks
#     396 for tag in soup(string='\n'):
#
# File c:\Python312\Lib\site-packages\bs4\__init__.py:473, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     471 self.builder.initialize_soup(self)
#     472 try:
# --> 473     self._feed()
#     474     success = True
#     475     break
#
# File c:\Python312\Lib\site-packages\bs4\__init__.py:658, in BeautifulSoup._feed(self)
#     655 self.builder.reset()
#     657 if self.markup is not None:
# --> 658     self.builder.feed(self.markup)
#     659 # Close out any unfinished strings and close all the open tags.
#     660 self.endData()
#
# File c:\Python312\Lib\site-packages\bs4\builder\_lxml.py:304, in LXMLTreeBuilderForXML.feed(self, markup)
#     302         data = io.read(self.CHUNK_SIZE)
#     303         if len(data) != 0:
# --> 304             self.parser.feed(data)
#     305     self.parser.close()
#     306 except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#
# File src\\lxml\\parser.pxi:1331, in lxml.etree._FeedParser.feed()
#
# File src\\lxml\\parser.pxi:1451, in lxml.etree._FeedParser.feed()
#
# File src\\lxml\\parsertarget.pxi:161, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src\\lxml\\parsertarget.pxi:156, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src\\lxml\\etree.pyx:351, in lxml.etree._ExceptionContext._raise_if_stored()
#
# File src\\lxml\\saxparser.pxi:391, in lxml.etree._handleSaxTargetStart()
#
# File src\\lxml\\saxparser.pxi:466, in lxml.etree._callTargetSaxStart()
#
# File src\\lxml\\parsertarget.pxi:94, in lxml.etree._PythonSaxParserTarget._handleSaxStart()
#
# File c:\Python312\Lib\site-packages\bs4\builder\_lxml.py:393, in LXMLTreeBuilderForXML.start(self, tag, attrs, nsmap)
#     391 namespace, tag = self._getNsTag(tag)
#     392 nsprefix = self._prefix_for_namespace(namespace)
# --> 393 self.soup.handle_starttag(
#     394     tag,
#     395     namespace,
#     396     nsprefix,
#     397     final_attrs,
#     398     namespaces=self.active_namespace_prefixes[-1],
#     399 )
#
# File c:\Python312\Lib\site-packages\bs4\__init__.py:1032, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#    1029 # Assume that this is either Tag or a subclass of Tag. If not,
#    1030 # the user brought type-unsafety upon themselves.
#    1031 tag_class = cast(Type[Tag], tag_class)
# -> 1032 tag = tag_class(
#    1033     self,
#    1034     self.builder,
#    1035     name,
#    1036     namespace,
#    1037     nsprefix,
#    1038     attrs,
#    1039     self.currentTag,
#    1040     self._most_recent_element,
#    1041     sourceline=sourceline,
#    1042     sourcepos=sourcepos,
#    1043     namespaces=namespaces,
#    1044 )
#    1045 if tag is None:
#    1046     return tag
#
# File c:\Python312\Lib\site-packages\bs4\element.py:1682, in Tag.__init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml, sourceline, sourcepos, can_be_empty_element, cdata_list_attributes, preserve_whitespace_tags, interesting_string_types, namespaces)
#    1678     self.attrs = builder._replace_cdata_list_attribute_values(
#    1679         self.name, attrs
#    1680     )
#    1681 else:
# -> 1682     self.attrs = attr_dict_class()
#    1683     # Make sure that the values of any multi-valued
#    1684     # attributes (e.g. when a Tag is copied) are stored in
#    1685     # new lists.
#    1686     for k, v in attrs.items():
#
# KeyboardInterrupt:
